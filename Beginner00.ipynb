# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4bdbc1b3-58f6-4520-9569-e7e2307aa15d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bdbc1b3-58f6-4520-9569-e7e2307aa15d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
data = pd.read_csv("Salary_dataset.csv")

# %%
#Removendo da tabela uma base não utilizada, para evitar que os dados irrelevantes impactem no resultado final do modelo
#O axis=1 serve para referenciar que estamos procurando por uma coluna, se fosse igual a 0, estariamos referenciando uma fileira
data = data.drop(["Unnamed: 0"],axis=1)
data.head()
# Out:
#    YearsExperience    Salary
# 0             1.20 39,344.00
# 1             1.40 46,206.00
# 2             1.60 37,732.00
# 3             2.10 43,526.00
# 4             2.30 39,892.00

# %%
# Configurando o estilo
sns.set_theme(palette=["#9b91c0"])

# Plot data points com seaborn
#O método joinplot é responsável por criar os gráfico
sns.jointplot(data=data, x="YearsExperience", y="Salary")

# %%
# Separate the features (YearsExperience) from the target variable (Salary)
X = data.YearsExperience
Y = data.Salary

#O algoritmo espera uma matriz com duas dimensões e meus dados possuem apenas uma dimensão, por isso é necessário remodelar
#Um array   1D é assim: [1, 2, 3, 4, 5]
#Um array 2d é como uma tabela, assim:
#[
#  [1, 2, 3],
#  [4, 5, 6],
#  [7, 8, 9]
#]

X = X.values.reshape(-1, 1)
Y = Y.values.reshape(-1, 1)

# %%
# Create a linear regression model
regression = LinearRegression()

# Treinando o modelo
regression.fit(X, Y)

# Predict the Salary values based on YearsExperience
#predictions = regression.predict(X)
# Out:
# LinearRegression()

# %%
# Criar um plot de regressão linear
plot = sns.lmplot(data=data, x='YearsExperience', y='Salary', aspect=1.5, height=6)

# Labels
plot.set_axis_labels('Years of Experience', 'Salary')

#Titulo
plt.title('Linear Regression: Years of Experience vs Salary')

# Mostrar o plor
plt.show()

# %%
# Organizar os dados de entrada em um array numpy
year_of_experience = [[15]]

# Fazer a previsão
previsao = regression.predict(year_of_experience)

# Exibir a previsão
print("Predicted salary for 15 years of experience : ", previsao[0][0])
# Out:
# Predicted salary for 10 years of experience :  166597.63878834937
